# %%
import pandas as pd
import numpy as np
import random
import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from sklearn.model_selection import train_test_split, StratifiedKFold  # <--- MODIFIED: Added StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.utils.class_weight import compute_class_weight

def set_seeds(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

SEED = 42
set_seeds(SEED)
# Out:
# /opt/miniconda3/envs/embodied/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# Acquire Data
# Collect, store, retrieve, query data

# Reading data from train.csv file
train = pd.read_csv('train.csv')

# %%
# Prepare data (i): exploration
# Explore data: preliminary analysis

print("Dataset shape:", train.shape)
print("\nFirst 5 rows of the dataset:")
display(train.head())

print("\nDataset info:")
train.info()

print("\nLabel distribution:")
display(train['label'].value_counts().sort_index())

print("\nMissing values check:")
display(train.isnull().sum())

print("\nBasic statistics:")
display(train.describe())
# Out:
# Dataset shape: (139930, 24)
#
# First 5 rows of the dataset:
#    id       country property_type furnishing_status  property_size_sqft  \
# 0   1  South Africa     Apartment    Semi-Furnished                1244
# 1   2  South Africa     Farmhouse    Semi-Furnished                4152
# 2   3       Germany     Farmhouse    Semi-Furnished                3714
# 3   4  South Africa     Townhouse   Fully-Furnished                 531
# 4   5        Canada         Villa    Semi-Furnished                3169
#
#      price  constructed_year  previous_owners  rooms  bathrooms  ...  \
# 0   224538              1990                4      8          8  ...
# 1   745104              2019                5      2          1  ...
# 2  1110959              2008                1      3          3  ...
# 3    99041              2007                6      3          3  ...
# 4  1107368              1985                0      5          2  ...
#
#    customer_salary  loan_amount  loan_tenure_years  monthly_expenses  \
# 0            16970       181465                 20              8605
# 1            21914       307953                 30              2510
# 2            17980       674720                 15              8805
# 3            17676        65833                 25              8965
# 4            95520       793316                 30             10615
#
#    down_payment  emi_to_income_ratio  satisfaction_score  \
# 0         43073                 0.08                   9
# 1        437151                 0.09                   6
# 2        436239                 0.33                   2
# 3         33208                 0.03                   3
# 4        314052                 0.05                  10
#
#    neighbourhood_rating  connectivity_score  label
# 0                     1                   2      0
# 1                     8                   1      0
# 2                     6                   6      0
# 3                     3                   4      0
# 4                     8                   2      1
#
# [5 rows x 24 columns]
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139930 entries, 0 to 139929
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       139930 non-null  int64
#  1   country                  139930 non-null  object
#  2   property_type            139930 non-null  object
#  3   furnishing_status        139930 non-null  object
#  4   property_size_sqft       139930 non-null  int64
#  5   price                    139930 non-null  int64
#  6   constructed_year         139930 non-null  int64
#  7   previous_owners          139930 non-null  int64
#  8   rooms                    139930 non-null  int64
#  9   bathrooms                139930 non-null  int64
#  10  garage                   139930 non-null  int64
#  11  garden                   139930 non-null  int64
#  12  crime_cases_reported     139930 non-null  int64
#  13  legal_cases_on_property  139930 non-null  int64
#  14  customer_salary          139930 non-null  int64
#  15  loan_amount              139930 non-null  int64
#  16  loan_tenure_years        139930 non-null  int64
#  17  monthly_expenses         139930 non-null  int64
#  18  down_payment             139930 non-null  int64
#  19  emi_to_income_ratio      139930 non-null  float64
#  20  satisfaction_score       139930 non-null  int64
#  21  neighbourhood_rating     139930 non-null  int64
#  22  connectivity_score       139930 non-null  int64
#  23  label                    139930 non-null  int64
# dtypes: float64(1), int64(20), object(3)
# memory usage: 25.6+ MB
#
# Label distribution:
# label
# 0    107610
# 1     32320
# Name: count, dtype: int64
# Missing values check:
# id                         0
# country                    0
# property_type              0
# furnishing_status          0
# property_size_sqft         0
# price                      0
# constructed_year           0
# previous_owners            0
# rooms                      0
# bathrooms                  0
# garage                     0
# garden                     0
# crime_cases_reported       0
# legal_cases_on_property    0
# customer_salary            0
# loan_amount                0
# loan_tenure_years          0
# monthly_expenses           0
# down_payment               0
# emi_to_income_ratio        0
# satisfaction_score         0
# neighbourhood_rating       0
# connectivity_score         0
# label                      0
# dtype: int64
# Basic statistics:
#                   id  property_size_sqft         price  constructed_year  \
# count  139930.000000       139930.000000  1.399300e+05     139930.000000
# mean    69965.500000         3196.275381  1.215876e+06       1991.456528
# std     40394.455921         1612.606112  8.243345e+05         18.496066
# min         1.000000          400.000000  5.628800e+04       1960.000000
# 25%     34983.250000         1805.000000  5.670900e+05       1975.000000
# 50%     69965.500000         3192.000000  1.023482e+06       1991.000000
# 75%    104947.750000         4587.000000  1.726123e+06       2007.000000
# max    139930.000000         6000.000000  4.202732e+06       2023.000000
#
#        previous_owners          rooms      bathrooms         garage  \
# count    139930.000000  139930.000000  139930.000000  139930.000000
# mean          3.004345       4.514300       2.757715       0.499150
# std           2.001356       2.294085       1.839882       0.500001
# min           0.000000       1.000000       1.000000       0.000000
# 25%           1.000000       3.000000       1.000000       0.000000
# 50%           3.000000       5.000000       2.000000       0.000000
# 75%           5.000000       7.000000       4.000000       1.000000
# max           6.000000       8.000000       8.000000       1.000000
#
#               garden  crime_cases_reported  ...  customer_salary  \
# count  139930.000000         139930.000000  ...    139930.000000
# mean        0.498656              1.230051  ...     46440.850289
# std         0.500000              1.186716  ...     27972.357740
# min         0.000000              0.000000  ...      2006.000000
# 25%         0.000000              0.000000  ...     21360.000000
# 50%         0.000000              1.000000  ...     41315.000000
# 75%         1.000000              2.000000  ...     70598.750000
# max         1.000000              9.000000  ...    100000.000000
#
#         loan_amount  loan_tenure_years  monthly_expenses  down_payment  \
# count  1.399300e+05      139930.000000     139930.000000  1.399300e+05
# mean   7.603534e+05          19.988101      10551.103916  4.555228e+05
# std    5.499271e+05           7.075541       5430.204202  3.626979e+05
# min    2.350400e+04          10.000000        500.000000  9.996000e+03
# 25%    3.379288e+05          15.000000       5760.000000  1.851872e+05
# 50%    6.263160e+05          20.000000      10495.000000  3.567975e+05
# 75%    1.059142e+06          25.000000      15250.000000  6.254765e+05
# max    3.520150e+06          30.000000      20000.000000  2.492723e+06
#
#        emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# count        139930.000000       139930.000000         139930.000000
# mean              0.195672            5.500908              5.503931
# std               0.219540            2.877524              2.867538
# min               0.000000            1.000000              1.000000
# 25%               0.070000            3.000000              3.000000
# 50%               0.130000            5.000000              5.000000
# 75%               0.240000            8.000000              8.000000
# max               3.310000           10.000000             10.000000
#
#        connectivity_score          label
# count       139930.000000  139930.000000
# mean             5.495684       0.230973
# std              2.871748       0.421456
# min              1.000000       0.000000
# 25%              3.000000       0.000000
# 50%              5.000000       0.000000
# 75%              8.000000       0.000000
# max             10.000000       1.000000
#
# [8 rows x 21 columns]

# %%
# Prepare data (ii): data preprocessing
# Data integration, Data cleaning, Feature extraction, Feature scaling

# Load test data for preprocessing
test_df = pd.read_csv('test.csv')
print("test.csv loaded successfully.")
test_ids = test_df['id']

# Define Features
print("1. Defining features...")
categorical_features = ['country', 'property_type', 'furnishing_status']
numerical_features = [
    'property_size_sqft', 'price', 'constructed_year', 'previous_owners', 
    'rooms', 'bathrooms', 'garage', 'garden', 'crime_cases_reported', 
    'legal_cases_on_property', 'customer_salary', 'loan_amount', 
    'loan_tenure_years', 'monthly_expenses', 'down_payment', 
    'emi_to_income_ratio', 'satisfaction_score', 'neighbourhood_rating', 
    'connectivity_score'
]

# Separate features and target (using full training data)
X = train.drop(['id', 'label'], axis=1)
y = train['label']
X_test_kaggle = test_df.drop('id', axis=1)

# --- K-Fold Cross-Validation Setup --- 
print("2. Setting up 5-Fold Stratified Cross-Validation...")
N_SPLITS = 5
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)

all_val_metrics = []
all_test_predictions = []
all_histories = []

# Helper function to build the model
def build_dnn_model(input_dim):
    print("5. Building DNN model...")
    tf.keras.backend.clear_session()
    model = Sequential([
        Input(shape=(input_dim,), name='Input_Layer'),
        Dense(128, activation='relu', name='Hidden_Layer_1'),
        Dropout(0.3, name='Dropout_1'),
        Dense(64, activation='relu', name='Hidden_Layer_2'),
        Dropout(0.2, name='Dropout_2'),
        Dense(32, activation='relu', name='Hidden_Layer_3'),
        Dense(1, activation='sigmoid', name='Output_Layer')
    ])
    
    print("6. Compiling model...")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.F1Score(average='macro', name='f1_macro')
        ]
    )
    return model

# Start K-Fold Loop
for fold, (train_index, val_index) in enumerate(skf.split(X, y)):
    print(f"\n--- FOLD {fold + 1}/{N_SPLITS} ---")
    
    # Split data for this fold
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    print(f"Training set size: {X_train.shape[0]}")
    print(f"Validation set size: {X_val.shape[0]}")

    # Create and Apply Preprocessing Pipeline
    print("3. Creating data preprocessing pipeline...")
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), numerical_features),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
        ],
        remainder='passthrough'
    )

    print("4. Preprocessing data...")
    # Fit on this fold's training data
    X_train_processed = preprocessor.fit_transform(X_train)
    # Transform validation and kaggle test data
    X_val_processed = preprocessor.transform(X_val)
    X_test_kaggle_processed = preprocessor.transform(X_test_kaggle)
    input_dim = X_train_processed.shape[1]
    print(f"Data preprocessing complete. DNN input dimension is: {input_dim}")

    # Analyze data
    # Build models, Select analytical techniques

    # Build and compile the model for this fold
    model = build_dnn_model(input_dim)
    if fold == 0:
        model.summary()

    # Define callbacks
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_f1_macro', # Monitoring F1 as in original file
        patience=10,
        mode='max',
        verbose=1,
        restore_best_weights=True
    )

    # Train the model for this fold
    print("7. Starting model training...")
    history = model.fit(
        X_train_processed,       
        y_train,                 
        epochs=100,            
        batch_size=64, # Using batch_size from original file
        validation_data=(X_val_processed, y_val),
        # class_weight=class_weights_dict, # Kept commented as in original file
        callbacks=[early_stopping],
        verbose=1
    )
    all_histories.append(history) # Store history for plotting

    # Evaluate the best model on this fold's validation set
    print(f"\n8. Evaluating Fold {fold + 1} model on the validation set...")
    val_metrics = model.evaluate(X_val_processed, y_val, verbose=0)
    all_val_metrics.append(val_metrics)
    
    metrics_names = model.metrics_names
    for name, value in zip(metrics_names, val_metrics):
        print(f"   Fold {fold + 1} Validation {name}: {value:.4f}")
    print(f"   Fold {fold + 1} Validation AUC: {val_metrics[2]:.4f}")
    print(f"   Fold {fold + 1} Validation Macro-F1: {val_metrics[3]:.4f}")

    # Predict on the Kaggle test set
    print(f"\n9. Predicting Fold {fold + 1} on the Kaggle test set (test.csv)...")
    y_pred_proba = model.predict(X_test_kaggle_processed)
    all_test_predictions.append(y_pred_proba)

# End of K-Fold Loop

print("5-Fold Cross-Validation Summary")
avg_metrics = np.mean(all_val_metrics, axis=0)
for name, value in zip(metrics_names, avg_metrics):
    print(f"   Average Validation {name}: {value:.4f}")
print(f"   Average Validation AUC: {avg_metrics[2]:.4f}")
print(f"   Average Validation Macro-F1: {avg_metrics[3]:.4f}")

# 10. Create final submission file based on averaged predictions
print("\n10. Creating submission.csv based on averaged 5-Fold predictions...")
averaged_proba = np.mean(all_test_predictions, axis=0)
y_pred_binary = (averaged_proba > 0.5).astype(int).flatten()

submission_df = pd.DataFrame({'id': test_ids, 'label': y_pred_binary})
submission_df.to_csv('submission_5fold_avg.csv', index=False)
print("\n'submission_5fold_avg.csv' has been successfully generated.")
# Out:
# test.csv loaded successfully.
# 1. Defining features...
# 2. Setting up 5-Fold Stratified Cross-Validation...
#
# --- FOLD 1/5 ---
# Training set size: 111944
# Validation set size: 27986
# 3. Creating data preprocessing pipeline...
# 4. Preprocessing data...
# Data preprocessing complete. DNN input dimension is: 41
# 5. Building DNN model...
# 6. Compiling model...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer_1 (Dense)          │ (None, 128)            │         5,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,745 (61.50 KB)
#  Trainable params: 15,745 (61.50 KB)
#  Non-trainable params: 0 (0.00 B)
# 7. Starting model training...
# Epoch 1/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 659us/step - accuracy: 0.9093 - auc: 0.9519 - f1_macro: 0.4104 - loss: 0.1896 - val_accuracy: 0.9972 - val_auc: 1.0000 - val_f1_macro: 0.6741 - val_loss: 0.0078
# Epoch 2/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step - accuracy: 0.9951 - auc: 0.9998 - f1_macro: 0.7073 - loss: 0.0129 - val_accuracy: 0.9984 - val_auc: 1.0000 - val_f1_macro: 0.7690 - val_loss: 0.0040
# Epoch 3/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - accuracy: 0.9975 - auc: 1.0000 - f1_macro: 0.7832 - loss: 0.0067 - val_accuracy: 0.9983 - val_auc: 1.0000 - val_f1_macro: 0.8116 - val_loss: 0.0037
# Epoch 4/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - accuracy: 0.9980 - auc: 0.9999 - f1_macro: 0.8173 - loss: 0.0053 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.8093 - val_loss: 0.0028
# Epoch 5/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 605us/step - accuracy: 0.9983 - auc: 1.0000 - f1_macro: 0.8347 - loss: 0.0044 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_f1_macro: 0.8473 - val_loss: 0.0033
# Epoch 6/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 558us/step - accuracy: 0.9985 - auc: 0.9999 - f1_macro: 0.8526 - loss: 0.0040 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.8399 - val_loss: 0.0026
# Epoch 7/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 559us/step - accuracy: 0.9985 - auc: 1.0000 - f1_macro: 0.8613 - loss: 0.0035 - val_accuracy: 0.9988 - val_auc: 1.0000 - val_f1_macro: 0.8770 - val_loss: 0.0028
# Epoch 8/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step - accuracy: 0.9987 - auc: 1.0000 - f1_macro: 0.8695 - loss: 0.0033 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.8847 - val_loss: 0.0027
# Epoch 9/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 564us/step - accuracy: 0.9989 - auc: 1.0000 - f1_macro: 0.8705 - loss: 0.0029 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.8582 - val_loss: 0.0025
# Epoch 10/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 615us/step - accuracy: 0.9989 - auc: 0.9999 - f1_macro: 0.8678 - loss: 0.0029 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.8801 - val_loss: 0.0025
# Epoch 11/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 565us/step - accuracy: 0.9988 - auc: 1.0000 - f1_macro: 0.8896 - loss: 0.0031 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.9070 - val_loss: 0.0029
# Epoch 12/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 589us/step - accuracy: 0.9990 - auc: 1.0000 - f1_macro: 0.9007 - loss: 0.0026 - val_accuracy: 0.9988 - val_auc: 1.0000 - val_f1_macro: 0.9144 - val_loss: 0.0025
# Epoch 13/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 579us/step - accuracy: 0.9988 - auc: 1.0000 - f1_macro: 0.8882 - loss: 0.0030 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9275 - val_loss: 0.0023
# Epoch 14/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 637us/step - accuracy: 0.9990 - auc: 1.0000 - f1_macro: 0.9068 - loss: 0.0025 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9369 - val_loss: 0.0023
# Epoch 15/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 586us/step - accuracy: 0.9990 - auc: 0.9999 - f1_macro: 0.9055 - loss: 0.0027 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9301 - val_loss: 0.0020
# Epoch 16/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9141 - loss: 0.0021 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_f1_macro: 0.9112 - val_loss: 0.0035
# Epoch 17/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - accuracy: 0.9990 - auc: 0.9999 - f1_macro: 0.9032 - loss: 0.0024 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9417 - val_loss: 0.0022
# Epoch 18/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 525us/step - accuracy: 0.9991 - auc: 0.9999 - f1_macro: 0.9203 - loss: 0.0023 - val_accuracy: 0.9983 - val_auc: 0.9999 - val_f1_macro: 0.9478 - val_loss: 0.0041
# Epoch 19/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 538us/step - accuracy: 0.9991 - auc: 1.0000 - f1_macro: 0.8984 - loss: 0.0027 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9548 - val_loss: 0.0021
# Epoch 20/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 553us/step - accuracy: 0.9994 - auc: 0.9999 - f1_macro: 0.9318 - loss: 0.0019 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9472 - val_loss: 0.0026
# Epoch 21/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9280 - loss: 0.0020 - val_accuracy: 0.9988 - val_auc: 1.0000 - val_f1_macro: 0.9626 - val_loss: 0.0026
# Epoch 22/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 543us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9438 - loss: 0.0019 - val_accuracy: 0.9991 - val_auc: 0.9999 - val_f1_macro: 0.9698 - val_loss: 0.0025
# Epoch 23/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 554us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9470 - loss: 0.0021 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9691 - val_loss: 0.0022
# Epoch 24/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 555us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9383 - loss: 0.0018 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9614 - val_loss: 0.0024
# Epoch 25/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 524us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9451 - loss: 0.0018 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9795 - val_loss: 0.0026
# Epoch 26/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 520us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9556 - loss: 0.0017 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9693 - val_loss: 0.0019
# Epoch 27/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 520us/step - accuracy: 0.9991 - auc: 1.0000 - f1_macro: 0.9498 - loss: 0.0023 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9725 - val_loss: 0.0033
# Epoch 28/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 529us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9371 - loss: 0.0022 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_f1_macro: 0.9620 - val_loss: 0.0032
# Epoch 29/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 552us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9357 - loss: 0.0019 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9762 - val_loss: 0.0019
# Epoch 30/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 522us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9568 - loss: 0.0014 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9771 - val_loss: 0.0022
# Epoch 31/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 514us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9612 - loss: 0.0013 - val_accuracy: 0.9985 - val_auc: 0.9999 - val_f1_macro: 0.9722 - val_loss: 0.0037
# Epoch 32/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 516us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9533 - loss: 0.0016 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9738 - val_loss: 0.0020
# Epoch 33/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 507us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9485 - loss: 0.0016 - val_accuracy: 0.9991 - val_auc: 0.9999 - val_f1_macro: 0.9667 - val_loss: 0.0026
# Epoch 34/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 516us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9393 - loss: 0.0012 - val_accuracy: 0.9990 - val_auc: 0.9998 - val_f1_macro: 0.9728 - val_loss: 0.0026
# Epoch 35/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 524us/step - accuracy: 0.9995 - auc: 0.9999 - f1_macro: 0.9441 - loss: 0.0014 - val_accuracy: 0.9985 - val_auc: 0.9997 - val_f1_macro: 0.9743 - val_loss: 0.0048
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
#
# 8. Evaluating Fold 1 model on the validation set...
#    Fold 1 Validation loss: 0.0026
#    Fold 1 Validation compile_metrics: 0.9989
#    Fold 1 Validation AUC: 1.0000
#    Fold 1 Validation Macro-F1: 0.9795
#
# 9. Predicting Fold 1 on the Kaggle test set (test.csv)...
# 1878/1878 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step
#
# --- FOLD 2/5 ---
# Training set size: 111944
# Validation set size: 27986
# 3. Creating data preprocessing pipeline...
# 4. Preprocessing data...
# Data preprocessing complete. DNN input dimension is: 41
# 5. Building DNN model...
# 6. Compiling model...
# 7. Starting model training...
# Epoch 1/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 598us/step - accuracy: 0
100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 514us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9820 - loss: 0.0010 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9872 - val_loss: 0.0031
# Epoch 52/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 517us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9817 - loss: 8.6940e-04 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9892 - val_loss: 0.0030
# Epoch 53/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 509us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9857 - loss: 0.0012 - val_accuracy: 0.9987 - val_auc: 0.9999 - val_f1_macro: 0.9860 - val_loss: 0.0041
# Epoch 54/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9819 - loss: 0.0013 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9896 - val_loss: 0.0027
# Epoch 55/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 527us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9853 - loss: 0.0010 - val_accuracy: 0.9991 - val_auc: 0.9999 - val_f1_macro: 0.9877 - val_loss: 0.0030
# Epoch 56/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 503us/step - accuracy: 0.9996 - auc: 0.9999 - f1_macro: 0.9787 - loss: 0.0011 - val_accuracy: 0.9981 - val_auc: 0.9997 - val_f1_macro: 0.9866 - val_loss: 0.0076
# Epoch 57/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 527us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9819 - loss: 0.0014 - val_accuracy: 0.9994 - val_auc: 0.9999 - val_f1_macro: 0.9887 - val_loss: 0.0022
# Epoch 58/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 505us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9833 - loss: 0.0012 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9893 - val_loss: 0.0024
# Epoch 59/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 514us/step - accuracy: 0.9994 - auc: 0.9999 - f1_macro: 0.9821 - loss: 0.0018 - val_accuracy: 0.9985 - val_auc: 0.9999 - val_f1_macro: 0.9859 - val_loss: 0.0044
# Epoch 60/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 499us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9790 - loss: 0.0014 - val_accuracy: 0.9985 - val_auc: 0.9999 - val_f1_macro: 0.9869 - val_loss: 0.0044
# Epoch 61/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 519us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9818 - loss: 9.9233e-04 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9888 - val_loss: 0.0017
# Epoch 62/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 508us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9850 - loss: 0.0010 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9879 - val_loss: 0.0034
# Epoch 63/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 519us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9834 - loss: 0.0010 - val_accuracy: 0.9987 - val_auc: 0.9999 - val_f1_macro: 0.9848 - val_loss: 0.0041
# Epoch 64/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 526us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9754 - loss: 0.0011 - val_accuracy: 0.9985 - val_auc: 0.9997 - val_f1_macro: 0.9857 - val_loss: 0.0055
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 54.
#
# 8. Evaluating Fold 2 model on the validation set...
#    Fold 2 Validation loss: 0.0027
#    Fold 2 Validation compile_metrics: 0.9992
#    Fold 2 Validation AUC: 1.0000
#    Fold 2 Validation Macro-F1: 0.9896
#
# 9. Predicting Fold 2 on the Kaggle test set (test.csv)...
# 1878/1878 ━━━━━━━━━━━━━━━━━━━━ 0s 158us/step
#
# --- FOLD 3/5 ---
# Training set size: 111944
# Validation set size: 27986
# 3. Creating data preprocessing pipeline...
# 4. Preprocessing data...
# Data preprocessing complete. DNN input dimension is: 41
# 5. Building DNN model...
# 6. Compiling model...
# 7. Starting model training...
# Epoch 1/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 580us/step - accuracy: 0.9226 - auc: 0.9611 - f1_macro: 0.4121 - loss: 0.1709 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_f1_macro: 0.6710 - val_loss: 0.0093
# Epoch 2/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 539us/step - accuracy: 0.9952 - auc: 0.9998 - f1_macro: 0.7102 - loss: 0.0136 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.7906 - val_loss: 0.0035
# Epoch 3/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 527us/step - accuracy: 0.9971 - auc: 0.9999 - f1_macro: 0.7926 - loss: 0.0074 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.8231 - val_loss: 0.0031
# Epoch 4/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 514us/step - accuracy: 0.9979 - auc: 0.9999 - f1_macro: 0.8350 - loss: 0.0054 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.8448 - val_loss: 0.0030
# Epoch 5/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 512us/step - accuracy: 0.9983 - auc: 1.0000 - f1_macro: 0.8568 - loss: 0.0044 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.8788 - val_loss: 0.0032
# Epoch 6/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 531us/step - accuracy: 0.
100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 959us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9718 - loss: 0.0016 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_f1_macro: 0.9856 - val_loss: 0.0016
# Epoch 37/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9670 - loss: 0.0021 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9809 - val_loss: 0.0021
# Epoch 38/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9628 - loss: 0.0013 - val_accuracy: 0.9993 - val_auc: 0.9999 - val_f1_macro: 0.9857 - val_loss: 0.0019
# Epoch 39/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9651 - loss: 0.0017 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_f1_macro: 0.9846 - val_loss: 0.0018
# Epoch 40/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9704 - loss: 0.0014 - val_accuracy: 0.9993 - val_auc: 1.0000 - val_f1_macro: 0.9827 - val_loss: 0.0019
# Epoch 41/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9709 - loss: 0.0015 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9830 - val_loss: 0.0027
# Epoch 42/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 988us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9799 - loss: 9.4912e-04 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9871 - val_loss: 0.0025
# Epoch 43/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9809 - loss: 0.0017 - val_accuracy: 0.9992 - val_auc: 0.9999 - val_f1_macro: 0.9863 - val_loss: 0.0021
# Epoch 44/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9755 - loss: 0.0020 - val_accuracy: 0.9993 - val_auc: 1.0000 - val_f1_macro: 0.9843 - val_loss: 0.0017
# Epoch 45/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 46s 26ms/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9788 - loss: 0.0017 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9880 - val_loss: 0.0016
# Epoch 46/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9792 - loss: 0.0013 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9863 - val_loss: 0.0023
# Epoch 47/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9782 - loss: 0.0014 - val_accuracy: 0.9992 - val_auc: 0.9999 - val_f1_macro: 0.9826 - val_loss: 0.0021
# Epoch 48/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9798 - loss: 0.0010 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9821 - val_loss: 0.0024
# Epoch 49/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9756 - loss: 0.0013 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9847 - val_loss: 0.0024
# Epoch 50/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 915us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9789 - loss: 0.0013 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9858 - val_loss: 0.0021
# Epoch 51/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 980s 560ms/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9798 - loss: 0.0013 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_f1_macro: 0.9842 - val_loss: 0.0024
# Epoch 52/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9762 - loss: 0.0011 - val_accuracy: 0.9992 - val_auc: 0.9999 - val_f1_macro: 0.9853 - val_loss: 0.0020
# Epoch 53/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 78s 45ms/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9780 - loss: 0.0010 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9849 - val_loss: 0.0028
# Epoch 54/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9797 - loss: 0.0016 - val_accuracy: 0.9991 - val_auc: 1.0000 - val_f1_macro: 0.9873 - val_loss: 0.0022
# Epoch 55/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9800 - loss: 0.0014 - val_accuracy: 0.9991 - val_auc: 0.9999 - val_f1_macro: 0.9873 - val_loss: 0.0021
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 45.
#
# 8. Evaluating Fold 3 model on the validation set...
#    Fold 3 Validation loss: 0.0016
#    Fold 3 Validation compile_metrics: 0.9992
#    Fold 3 Validation AUC: 1.0000
#    Fold 3 Validation Macro-F1: 0.9880
#
# 9. Predicting Fold 3 on the Kaggle test set (test.csv)...
# 1878/1878 ━━━━━━━━━━━━━━━━━━━━ 1s 620us/step
#
# --- FOLD 4/5 ---
# Training set size: 111944
# Validation set size: 27986
# 3. Creating data preprocessing pipeline...
# 4. Preprocessing data...
# Data preprocessing complete. DNN input dimension is: 41
# 5. Building DNN model...
# 6. Compiling model...
# 7. Starting model training...
# Epoch 1/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.
100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 514us/step - accuracy: 0.9991 - auc: 1.0000 - f1_macro: 0.9543 - loss: 0.0024 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9787 - val_loss: 0.0026
# Epoch 23/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9556 - loss: 0.0020 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_f1_macro: 0.9700 - val_loss: 0.0034
# Epoch 24/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - accuracy: 0.9991 - auc: 0.9999 - f1_macro: 0.9386 - loss: 0.0031 - val_accuracy: 0.9988 - val_auc: 1.0000 - val_f1_macro: 0.9795 - val_loss: 0.0027
# Epoch 25/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 611us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9499 - loss: 0.0023 - val_accuracy: 0.9987 - val_auc: 0.9999 - val_f1_macro: 0.9810 - val_loss: 0.0036
# Epoch 26/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 559us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9540 - loss: 0.0021 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.9795 - val_loss: 0.0027
# Epoch 27/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 576us/step - accuracy: 0.9992 - auc: 0.9999 - f1_macro: 0.9481 - loss: 0.0022 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_f1_macro: 0.9833 - val_loss: 0.0036
# Epoch 28/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 599us/step - accuracy: 0.9990 - auc: 1.0000 - f1_macro: 0.9559 - loss: 0.0022 - val_accuracy: 0.9983 - val_auc: 1.0000 - val_f1_macro: 0.9811 - val_loss: 0.0045
# Epoch 29/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 555us/step - accuracy: 0.9993 - auc: 0.9999 - f1_macro: 0.9553 - loss: 0.0019 - val_accuracy: 0.9986 - val_auc: 0.9997 - val_f1_macro: 0.9856 - val_loss: 0.0041
# Epoch 30/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 573us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9583 - loss: 0.0023 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9831 - val_loss: 0.0024
# Epoch 31/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 572us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9664 - loss: 0.0015 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9831 - val_loss: 0.0031
# Epoch 32/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 578us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9670 - loss: 0.0019 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_f1_macro: 0.9856 - val_loss: 0.0030
# Epoch 33/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 580us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9672 - loss: 0.0022 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9804 - val_loss: 0.0026
# Epoch 34/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 601us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9654 - loss: 0.0017 - val_accuracy: 0.9986 - val_auc: 0.9998 - val_f1_macro: 0.9853 - val_loss: 0.0037
# Epoch 35/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 599us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9711 - loss: 0.0016 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9824 - val_loss: 0.0030
# Epoch 36/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 571us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9634 - loss: 0.0020 - val_accuracy: 0.9987 - val_auc: 0.9999 - val_f1_macro: 0.9845 - val_loss: 0.0032
# Epoch 37/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 608us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9649 - loss: 0.0014 - val_accuracy: 0.9990 - val_auc: 0.9998 - val_f1_macro: 0.9844 - val_loss: 0.0030
# Epoch 38/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 609us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9680 - loss: 0.0015 - val_accuracy: 0.9987 - val_auc: 0.9999 - val_f1_macro: 0.9833 - val_loss: 0.0035
# Epoch 39/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9700 - loss: 0.0021 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9813 - val_loss: 0.0031
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
#
# 8. Evaluating Fold 4 model on the validation set...
#    Fold 4 Validation loss: 0.0041
#    Fold 4 Validation compile_metrics: 0.9986
#    Fold 4 Validation AUC: 0.9997
#    Fold 4 Validation Macro-F1: 0.9856
#
# 9. Predicting Fold 4 on the Kaggle test set (test.csv)...
# 1878/1878 ━━━━━━━━━━━━━━━━━━━━ 0s 163us/step
#
# --- FOLD 5/5 ---
# Training set size: 111944
# Validation set size: 27986
# 3. Creating data preprocessing pipeline...
# 4. Preprocessing data...
# Data preprocessing complete. DNN input dimension is: 41
# 5. Building DNN model...
# 6. Compiling model...
# 7. Starting model training...
# Epoch 1/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 2s 660us/step - accuracy: 0.9242 - auc: 0.9658 - f1_macro: 0.4130 - loss: 0.1660 - val_accuracy: 0.9962 - val_auc: 0.9999 - val_f1_macro: 0.6765 - val_loss: 0.0093
# Epoch 2/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 580us/step - accuracy: 0.9948 - auc: 0.9998 - f1_macro: 0.7087 - loss: 0.0134 - val_accuracy: 0.9983 - val_auc: 1.0000 - val_f1_macro: 0.7743 - val_loss: 0.0040
# Epoch 3/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 583us/step - accuracy: 0.9973 - auc: 1.0000 - f1_macro: 0.7899 - loss: 0.0071 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0
100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 658us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9531 - loss: 0.0018 - val_accuracy: 0.9986 - val_auc: 0.9999 - val_f1_macro: 0.9650 - val_loss: 0.0037
# Epoch 30/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 576us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9501 - loss: 0.0016 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9779 - val_loss: 0.0024
# Epoch 31/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 534us/step - accuracy: 0.9991 - auc: 1.0000 - f1_macro: 0.9490 - loss: 0.0021 - val_accuracy: 0.9988 - val_auc: 0.9999 - val_f1_macro: 0.9771 - val_loss: 0.0032
# Epoch 32/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 533us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9627 - loss: 0.0018 - val_accuracy: 0.9986 - val_auc: 0.9996 - val_f1_macro: 0.9839 - val_loss: 0.0044
# Epoch 33/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 551us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9597 - loss: 0.0020 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.9853 - val_loss: 0.0032
# Epoch 34/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 657us/step - accuracy: 0.9992 - auc: 1.0000 - f1_macro: 0.9611 - loss: 0.0018 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9824 - val_loss: 0.0021
# Epoch 35/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9640 - loss: 0.0014 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9779 - val_loss: 0.0029
# Epoch 36/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9602 - loss: 0.0016 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9848 - val_loss: 0.0027
# Epoch 37/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 571us/step - accuracy: 0.9993 - auc: 1.0000 - f1_macro: 0.9760 - loss: 0.0017 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.9831 - val_loss: 0.0028
# Epoch 38/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9714 - loss: 0.0014 - val_accuracy: 0.9988 - val_auc: 0.9999 - val_f1_macro: 0.9859 - val_loss: 0.0034
# Epoch 39/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 589us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9624 - loss: 0.0016 - val_accuracy: 0.9987 - val_auc: 0.9997 - val_f1_macro: 0.9880 - val_loss: 0.0037
# Epoch 40/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 572us/step - accuracy: 0.9990 - auc: 1.0000 - f1_macro: 0.9745 - loss: 0.0022 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9836 - val_loss: 0.0024
# Epoch 41/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 611us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9759 - loss: 0.0014 - val_accuracy: 0.9988 - val_auc: 0.9999 - val_f1_macro: 0.9878 - val_loss: 0.0032
# Epoch 42/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 565us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9814 - loss: 0.0010 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9864 - val_loss: 0.0026
# Epoch 43/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 553us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9765 - loss: 0.0016 - val_accuracy: 0.9983 - val_auc: 0.9997 - val_f1_macro: 0.9869 - val_loss: 0.0054
# Epoch 44/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9765 - loss: 0.0014 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9869 - val_loss: 0.0026
# Epoch 45/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 585us/step - accuracy: 0.9995 - auc: 0.9999 - f1_macro: 0.9756 - loss: 0.0017 - val_accuracy: 0.9989 - val_auc: 0.9998 - val_f1_macro: 0.9867 - val_loss: 0.0033
# Epoch 46/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 577us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9761 - loss: 9.8398e-04 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9888 - val_loss: 0.0027
# Epoch 47/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 566us/step - accuracy: 0.9994 - auc: 0.9999 - f1_macro: 0.9764 - loss: 0.0016 - val_accuracy: 0.9988 - val_auc: 1.0000 - val_f1_macro: 0.9830 - val_loss: 0.0030
# Epoch 48/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 565us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9665 - loss: 0.0016 - val_accuracy: 0.9989 - val_auc: 0.9999 - val_f1_macro: 0.9821 - val_loss: 0.0027
# Epoch 49/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 577us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9688 - loss: 0.0011 - val_accuracy: 0.9989 - val_auc: 0.9998 - val_f1_macro: 0.9851 - val_loss: 0.0036
# Epoch 50/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 579us/step - accuracy: 0.9994 - auc: 1.0000 - f1_macro: 0.9727 - loss: 0.0015 - val_accuracy: 0.9987 - val_auc: 0.9999 - val_f1_macro: 0.9866 - val_loss: 0.0031
# Epoch 51/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 577us/step - accuracy: 0.9996 - auc: 0.9999 - f1_macro: 0.9787 - loss: 0.0015 - val_accuracy: 0.9984 - val_auc: 0.9995 - val_f1_macro: 0.9904 - val_loss: 0.0056
# Epoch 52/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 573us/step - accuracy: 0.9993 - auc: 0.9999 - f1_macro: 0.9756 - loss: 0.0021 - val_accuracy: 0.9990 - val_auc: 0.9999 - val_f1_macro: 0.9860 - val_loss: 0.0030
# Epoch 53/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 571us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9800 - loss: 7.9003e-04 - val_accuracy: 0.9988 - val_auc: 0.9997 - val_f1_macro: 0.9883 - val_loss: 0.0035
# Epoch 54/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 590us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9824 - loss: 0.0013 - val_accuracy: 0.9983 - val_auc: 0.9998 - val_f1_macro: 0.9874 - val_loss: 0.0045
# Epoch 55/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 580us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9794 - loss: 0.0010 - val_accuracy: 0.9991 - val_auc: 0.9998 - val_f1_macro: 0.9896 - val_loss: 0.0031
# Epoch 56/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 552us/step - accuracy: 0.9996 - auc: 0.9999 - f1_macro: 0.9829 - loss: 0.0012 - val_accuracy: 0.9987 - val_auc: 0.9997 - val_f1_macro: 0.9897 - val_loss: 0.0041
# Epoch 57/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 589us/step - accuracy: 0.9995 - auc: 0.9999 - f1_macro: 0.9824 - loss: 0.0017 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.9842 - val_loss: 0.0038
# Epoch 58/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 565us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9778 - loss: 8.8189e-04 - val_accuracy: 0.9989 - val_auc: 1.0000 - val_f1_macro: 0.9863 - val_loss: 0.0033
# Epoch 59/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 568us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9827 - loss: 0.0011 - val_accuracy: 0.9991 - val_auc: 0.9998 - val_f1_macro: 0.9884 - val_loss: 0.0031
# Epoch 60/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 570us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9857 - loss: 9.7793e-04 - val_accuracy: 0.9989 - val_auc: 0.9996 - val_f1_macro: 0.9919 - val_loss: 0.0039
# Epoch 61/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 566us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9856 - loss: 0.0013 - val_accuracy: 0.9985 - val_auc: 0.9991 - val_f1_macro: 0.9926 - val_loss: 0.0060
# Epoch 62/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 591us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9837 - loss: 0.0015 - val_accuracy: 0.9990 - val_auc: 0.9998 - val_f1_macro: 0.9881 - val_loss: 0.0029
# Epoch 63/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 552us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9835 - loss: 0.0011 - val_accuracy: 0.9989 - val_auc: 0.9997 - val_f1_macro: 0.9885 - val_loss: 0.0037
# Epoch 64/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - accuracy: 0.9997 - auc: 0.9999 - f1_macro: 0.9823 - loss: 0.0013 - val_accuracy: 0.9988 - val_auc: 0.9999 - val_f1_macro: 0.9860 - val_loss: 0.0036
# Epoch 65/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 569us/step - accuracy: 0.9996 - auc: 1.0000 - f1_macro: 0.9815 - loss: 0.0012 - val_accuracy: 0.9990 - val_auc: 0.9998 - val_f1_macro: 0.9879 - val_loss: 0.0034
# Epoch 66/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 553us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9843 - loss: 9.8066e-04 - val_accuracy: 0.9987 - val_auc: 0.9997 - val_f1_macro: 0.9869 - val_loss: 0.0039
# Epoch 67/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 590us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9832 - loss: 0.0010 - val_accuracy: 0.9988 - val_auc: 0.9997 - val_f1_macro: 0.9894 - val_loss: 0.0036
# Epoch 68/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 570us/step - accuracy: 0.9995 - auc: 0.9999 - f1_macro: 0.9823 - loss: 0.0016 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_f1_macro: 0.9866 - val_loss: 0.0036
# Epoch 69/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 550us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9831 - loss: 9.0805e-04 - val_accuracy: 0.9987 - val_auc: 0.9998 - val_f1_macro: 0.9885 - val_loss: 0.0034
# Epoch 70/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 604us/step - accuracy: 0.9995 - auc: 1.0000 - f1_macro: 0.9847 - loss: 0.0013 - val_accuracy: 0.9987 - val_auc: 0.9998 - val_f1_macro: 0.9894 - val_loss: 0.0039
# Epoch 71/100
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 1s 567us/step - accuracy: 0.9997 - auc: 1.0000 - f1_macro: 0.9854 - loss: 7.0541e-04 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_f1_macro: 0.9871 - val_loss: 0.0024
# Epoch 71: early stopping
# Restoring model weights from the end of the best epoch: 61.
#
# 8. Evaluating Fold 5 model on the validation set...
#    Fold 5 Validation loss: 0.0060
#    Fold 5 Validation compile_metrics: 0.9985
#    Fold 5 Validation AUC: 0.9991
#    Fold 5 Validation Macro-F1: 0.9926
#
# 9. Predicting Fold 5 on the Kaggle test set (test.csv)...
# 1878/1878 ━━━━━━━━━━━━━━━━━━━━ 0s 185us/step
#
# --- 5-Fold Cross-Validation Summary ---
#    Average Validation loss: 0.0034
#    Average Validation compile_metrics: 0.9989
#    Average Validation AUC: 0.9998
#    Average Validation Macro-F1: 0.9871
#
# 10. Creating submission.csv based on averaged 5-Fold predictions...
#
# 'submission_5fold_avg.csv' has been successfully generated.

# %%
# Report
# Data and result visualization

print("Plotting training history (for Fold 1 as representative)...")

if 'all_histories' in locals() and all_histories:
    # Use the history from the first fold for visualization
    history = all_histories[0]
    
    # Create a figure with subplots
    fig, axs = plt.subplots(2, 2, figsize=(16, 10))
    fig.suptitle('Model Training History (Fold 1)', fontsize=16) # MODIFIED: Added Fold 1 to title

    # Plot training & validation accuracy values
    axs[0, 0].plot(history.history['accuracy'])
    axs[0, 0].plot(history.history['val_accuracy'])
    axs[0, 0].set_title('Model Accuracy')
    axs[0, 0].set_ylabel('Accuracy')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].legend(['Train', 'Validation'], loc='upper left')
    axs[0, 0].grid(True)

    # Plot training & validation loss values
    axs[0, 1].plot(history.history['loss'])
    axs[0, 1].plot(history.history['val_loss'])
    axs[0, 1].set_title('Model Loss')
    axs[0, 1].set_ylabel('Loss')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].legend(['Train', 'Validation'], loc='upper left')
    axs[0, 1].grid(True)

    # Plot training & validation AUC values
    axs[1, 0].plot(history.history['auc'])
    axs[1, 0].plot(history.history['val_auc'])
    axs[1, 0].set_title('Model AUC')
    axs[1, 0].set_ylabel('AUC')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].legend(['Train', 'Validation'], loc='upper left')
    axs[1, 0].grid(True)

    # Plot training & validation F1-score values
    axs[1, 1].plot(history.history['f1_macro'])
    axs[1, 1].plot(history.history['val_f1_macro'])
    axs[1, 1].set_title('Model Macro-F1 Score')
    axs[1, 1].set_ylabel('F1 Score')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].legend(['Train', 'Validation'], loc='upper left')
    axs[1, 1].grid(True)

    # Adjust layout and show the plots
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
else:
    print("Could not find 'all_histories' object. Please ensure the model training cell has been run.")
# Out:
# Plotting training history (for Fold 1 as representative)...
